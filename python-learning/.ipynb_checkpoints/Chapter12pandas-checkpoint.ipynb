# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
datas = pd.date_range("20130101", periods=6)
datas
list("4456")
# Out:
# ['4', '4', '5', '6']

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=datas, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -1.721263 -0.560737 -1.376799 -0.674844
# 2013-01-02  0.760813  0.871411 -1.067692  1.793247
# 2013-01-03 -0.255980 -0.143875 -1.349752  0.423320
# 2013-01-04 -1.453006  0.251494 -1.474721  1.019450
# 2013-01-05  1.221905  0.329340  2.488125  0.463497
# 2013-01-06 -3.119465  1.422875  0.492012  0.195771

# %%
df2 = pd.DataFrame({'A' : 1.,
                    'B' : pd.Timestamp('20130102'),
                    'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
                    'D' : np.array([3] * 4,dtype='int32'),
                    'E' : pd.Categorical(["test","train","test","train"]),
                    'F' : 'foo' })

df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.tail()
# Out:
#                    A         B         C         D
# 2013-01-02  0.760813  0.871411 -1.067692  1.793247
# 2013-01-03 -0.255980 -0.143875 -1.349752  0.423320
# 2013-01-04 -1.453006  0.251494 -1.474721  1.019450
# 2013-01-05  1.221905  0.329340  2.488125  0.463497
# 2013-01-06 -3.119465  1.422875  0.492012  0.195771

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index([u'A', u'B', u'C', u'D'], dtype='object')

# %%
df.values
# Out:
# array([[-1.72126302, -0.56073706, -1.37679942, -0.67484364],
#        [ 0.7608128 ,  0.87141137, -1.0676921 ,  1.79324713],
#        [-0.25598012, -0.14387502, -1.34975246,  0.42332011],
#        [-1.45300587,  0.25149352, -1.47472112,  1.01944964],
#        [ 1.2219048 ,  0.32934027,  2.4881246 ,  0.46349659],
#        [-3.11946484,  1.42287544,  0.49201182,  0.1957708 ]])

# %%
df.merge?

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.761166  0.361751 -0.381471  0.536740
# std    1.641110  0.707897  1.586940  0.826346
# min   -3.119465 -0.560737 -1.474721 -0.674844
# 25%   -1.654199 -0.045033 -1.370038  0.252658
# 50%   -0.854493  0.290417 -1.208722  0.443408
# 75%    0.506615  0.735894  0.102086  0.880461
# max    1.221905  1.422875  2.488125  1.793247

# %%
df.sort_values('A')
# Out:
#                    A         B         C         D
# 2013-01-06 -3.119465  1.422875  0.492012  0.195771
# 2013-01-01 -1.721263 -0.560737 -1.376799 -0.674844
# 2013-01-04 -1.453006  0.251494 -1.474721  1.019450
# 2013-01-03 -0.255980 -0.143875 -1.349752  0.423320
# 2013-01-02  0.760813  0.871411 -1.067692  1.793247
# 2013-01-05  1.221905  0.329340  2.488125  0.463497

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01 -1.721263 -0.560737 -1.376799 -0.674844
# 2013-01-02  0.760813  0.871411 -1.067692  1.793247
# 2013-01-03 -0.255980 -0.143875 -1.349752  0.423320
# 2013-01-04 -1.453006  0.251494 -1.474721  1.019450
# 2013-01-05  1.221905  0.329340  2.488125  0.463497
# 2013-01-06 -3.119465  1.422875  0.492012  0.195771

# %%
df.sort_index(ascending=True)
# Out:
#                    A         B         C         D
# 2013-01-01 -1.721263 -0.560737 -1.376799 -0.674844
# 2013-01-02  0.760813  0.871411 -1.067692  1.793247
# 2013-01-03 -0.255980 -0.143875 -1.349752  0.423320
# 2013-01-04 -1.453006  0.251494 -1.474721  1.019450
# 2013-01-05  1.221905  0.329340  2.488125  0.463497
# 2013-01-06 -3.119465  1.422875  0.492012  0.195771

# %%
df.sort_values(by="2013-01-01", axis=1, ascending=True)
# Out:
#                    A         C         D         B
# 2013-01-01 -1.721263 -1.376799 -0.674844 -0.560737
# 2013-01-02  0.760813 -1.067692  1.793247  0.871411
# 2013-01-03 -0.255980 -1.349752  0.423320 -0.143875
# 2013-01-04 -1.453006 -1.474721  1.019450  0.251494
# 2013-01-05  1.221905  2.488125  0.463497  0.329340
# 2013-01-06 -3.119465  0.492012  0.195771  1.422875

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01 -1.721263 -0.560737 -1.376799 -0.674844
# 2013-01-02  0.760813  0.871411 -1.067692  1.793247
# 2013-01-03 -0.255980 -0.143875 -1.349752  0.423320
# 2013-01-04 -1.453006  0.251494 -1.474721  1.019450
# 2013-01-05  1.221905  0.329340  2.488125  0.463497
# 2013-01-06 -3.119465  1.422875  0.492012  0.195771

# %%
df.loc[datas[2],'A']
# Out:
# -0.25598011997384323

# %%
df.iloc[1]
# Out:
# A    0.760813
# B    0.871411
# C   -1.067692
# D    1.793247
# Name: 2013-01-02 00:00:00, dtype: float64

# %%
df.iat[0, 0]
# Out:
# -1.7212630203892982

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01       NaN       NaN       NaN       NaN
# 2013-01-02  0.760813  0.871411       NaN  1.793247
# 2013-01-03       NaN       NaN       NaN  0.423320
# 2013-01-04       NaN  0.251494       NaN  1.019450
# 2013-01-05  1.221905  0.329340  2.488125  0.463497
# 2013-01-06       NaN  1.422875  0.492012  0.195771

# %%
df2= df.copy()
df2['E'] = list('ABCDEF')
df2[df2['E'].isin(['A','D'])]
# Out:
#                    A         B         C         D  E
# 2013-01-01 -1.721263 -0.560737 -1.376799 -0.674844  A
# 2013-01-04 -1.453006  0.251494 -1.474721  1.019450  D

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range('20130102', periods=6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df['F'] = s1
df
# Out:
#                    A         B         C         D    F
# 2013-01-01 -1.721263 -0.560737 -1.376799 -0.674844  NaN
# 2013-01-02  0.760813  0.871411 -1.067692  1.793247  1.0
# 2013-01-03 -0.255980 -0.143875 -1.349752  0.423320  2.0
# 2013-01-04 -1.453006  0.251494 -1.474721  1.019450  3.0
# 2013-01-05  1.221905  0.329340  2.488125  0.463497  4.0
# 2013-01-06 -3.119465  1.422875  0.492012  0.195771  5.0

# %%
df.at[datas[0], 'A'] = 0
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.000000 -0.560737 -1.376799 -0.674844  NaN
# 2013-01-02  0.760813  0.871411 -1.067692  1.793247  1.0
# 2013-01-03 -0.255980 -0.143875 -1.349752  0.423320  2.0
# 2013-01-04 -1.453006  0.251494 -1.474721  1.019450  3.0
# 2013-01-05  1.221905  0.329340  2.488125  0.463497  4.0
# 2013-01-06 -3.119465  1.422875  0.492012  0.195771  5.0

# %%
df.iat[0, 1] = 0
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.000000  0.000000 -1.376799 -0.674844  NaN
# 2013-01-02  0.760813  0.871411 -1.067692  1.793247  1.0
# 2013-01-03 -0.255980 -0.143875 -1.349752  0.423320  2.0
# 2013-01-04 -1.453006  0.251494 -1.474721  1.019450  3.0
# 2013-01-05  1.221905  0.329340  2.488125  0.463497  4.0
# 2013-01-06 -3.119465  1.422875  0.492012  0.195771  5.0

# %%
df.loc[:,'D'] = np.array([5] * len(df))
df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -1.376799  5  NaN
# 2013-01-02  0.760813  0.871411 -1.067692  5  1.0
# 2013-01-03 -0.255980 -0.143875 -1.349752  5  2.0
# 2013-01-04 -1.453006  0.251494 -1.474721  5  3.0
# 2013-01-05  1.221905  0.329340  2.488125  5  4.0
# 2013-01-06 -3.119465  1.422875  0.492012  5  5.0

# %%
df2 = df.copy()
#df2[df2 > 0] = -df
df2 > 0
# Out:
#                 A      B      C     D      F
# 2013-01-01  False  False  False  True  False
# 2013-01-02   True   True  False  True   True
# 2013-01-03  False  False  False  True   True
# 2013-01-04  False   True  False  True   True
# 2013-01-05   True   True   True  True   True
# 2013-01-06  False   True   True  True   True

# %%
df1 = df.reindex(index=datas[0:4], columns=list(df.columns) + ['G', 'F'])
df1.loc['2013-01-02':datas[1],'D':'F'] = 1
df1
# Out:
#               A    B   C    D    G    F
# 2013-01-01  NaN  NaN NaN  NaN  NaN  NaN
# 2013-01-02  NaN  NaN NaN  1.0  1.0  1.0
# 2013-01-03  NaN  NaN NaN  NaN  NaN  NaN
# 2013-01-04  NaN  NaN NaN  NaN  NaN  NaN

# %%
df1.dropna(how='any')
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, F, E]
# Index: []

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  1.000000  1.000000  1.000000  5  5.0  5.0
# 2013-01-02  1.000000  1.000000  1.000000  5  1.0  5.0
# 2013-01-03 -0.255980 -0.143875 -1.349752  5  2.0  5.0
# 2013-01-04 -1.453006  0.251494 -1.474721  5  3.0  5.0

# %%
pd.isnull(df1)
# Out:
#                 A      B      C      D      F     E
# 2013-01-01  False  False  False  False   True  True
# 2013-01-02  False  False  False  False  False  True
# 2013-01-03  False  False  False  False  False  True
# 2013-01-04  False  False  False  False  False  True

# %%
df.mean(1)
# Out:
# 2013-01-01    0.905800
# 2013-01-02    1.312906
# 2013-01-03    1.050078
# 2013-01-04    1.064753
# 2013-01-05    2.607874
# 2013-01-06    1.759084
# Freq: D, dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=datas).shift(2)
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis='index')
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -1.255980 -1.143875 -2.349752  4.0  1.0
# 2013-01-04 -4.453006 -2.748506 -4.474721  2.0  0.0
# 2013-01-05 -3.778095 -4.670660 -2.511875  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %%
np.nan + 1
# Out:
# nan

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C   D     F
# 2013-01-01  0.000000  0.000000 -1.376799   5   NaN
# 2013-01-02  0.760813  0.871411 -2.444492  10   1.0
# 2013-01-03  0.504833  0.727536 -3.794244  15   3.0
# 2013-01-04 -0.948173  0.979030 -5.268965  20   6.0
# 2013-01-05  0.273732  1.308370 -2.780841  25  10.0
# 2013-01-06 -2.845733  2.731246 -2.288829  30  15.0

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    4.341370
# B    1.566750
# C    3.962846
# D    0.000000
# F    4.000000
# dtype: float64

# %%
s = pd.Series(np.random.randint(0, 7, size=10))
s
# Out:
# 0    2
# 1    6
# 2    1
# 3    2
# 4    3
# 5    4
# 6    1
# 7    4
# 8    6
# 9    5
# dtype: int64

# %%
s.value_counts()
# Out:
# 6    2
# 4    2
# 2    2
# 1    2
# 5    1
# 3    1
# dtype: int64

# %%
h = s.hist()

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
np.nan + 1
# Out:
# nan

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0  2.394728 -0.162601  0.537878 -1.987924
# 1  1.074728 -2.024222  0.350567  0.934784
# 2 -0.327412  0.674314  1.354195 -0.346598
# 3 -2.770225  0.185387  1.546528  2.048013
# 4  0.250237 -0.339961  0.488626 -1.333243
# 5  0.000745 -0.818255  0.265643 -0.529057
# 6 -0.555222 -0.587187 -1.055082  0.390221
# 7 -0.588623  0.037781 -1.039933 -0.688487
# 8  0.513988 -1.016469  0.424767 -0.074901
# 9  0.017121  0.428635  0.423028 -0.880208

# %%
pieces = [df[:2], df[4:5], df[7:]]
pd.concat(pieces, keys=list('abc'))
# Out:
#             0         1         2         3
# a 0  2.394728 -0.162601  0.537878 -1.987924
#   1  1.074728 -2.024222  0.350567  0.934784
# b 4  0.250237 -0.339961  0.488626 -1.333243
# c 7 -0.588623  0.037781 -1.039933 -0.688487
#   8  0.513988 -1.016469  0.424767 -0.074901
#   9  0.017121  0.428635  0.423028 -0.880208

# %%
left = pd.DataFrame({'key':['foo', 'foo'], 'lval':[1, 2]})
right = pd.DataFrame({'key':['foo', 'foo'], 'rval':[3, 4]})
print left
print right
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2
#    key  rval
# 0  foo     3
# 1  foo     4

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     3
# 1  foo     1     4
# 2  foo     2     3
# 3  foo     2     4

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=list('ABCD'))
df
# Out:
#           A         B         C         D
# 0  0.237419  0.363179 -1.594453 -1.141462
# 1 -1.296754 -0.564436 -0.240425 -0.514592
# 2  0.910429 -1.159316  0.057133 -0.103789
# 3  1.886726  1.125847 -0.115825 -0.941348
# 4 -0.072445  1.506019  0.025050  0.183108
# 5 -0.310354 -1.051345 -1.528043  2.759756
# 6  1.297992 -0.732210 -0.547869 -0.177043
# 7 -0.277692  1.019428  0.144993  0.602161

# %%
s = df.iloc[3]
df.append(s, ignore_index=True)
# Out:
#           A         B         C         D
# 0  0.237419  0.363179 -1.594453 -1.141462
# 1 -1.296754 -0.564436 -0.240425 -0.514592
# 2  0.910429 -1.159316  0.057133 -0.103789
# 3  1.886726  1.125847 -0.115825 -0.941348
# 4 -0.072445  1.506019  0.025050  0.183108
# 5 -0.310354 -1.051345 -1.528043  2.759756
# 6  1.297992 -0.732210 -0.547869 -0.177043
# 7 -0.277692  1.019428  0.144993  0.602161
# 8  1.886726  1.125847 -0.115825 -0.941348

# %%
df = pd.DataFrame({
    'A' : ['foo', 'bar', 'foo', 'bar',
                          'foo', 'bar', 'foo', 'foo'],
                   'B' : ['one', 'one', 'two', 'three',
                          'two', 'two', 'one', 'three'],
                   'C' : np.random.randn(8),
                   'D' : np.random.randn(8)
})
df
# Out:
#      A      B         C         D
# 0  foo    one -0.640799 -0.305273
# 1  bar    one -1.356075  0.651831
# 2  foo    two -0.068666  0.774003
# 3  bar  three  1.560698 -1.056592
# 4  foo    two -1.006171  0.124173
# 5  bar    two  0.392527 -1.364255
# 6  foo    one  1.183829 -0.594805
# 7  foo  three -0.225174  1.032530

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar  0.597150 -1.769015
# foo -0.756981  1.030629

# %%
zip(*[['bar', 'bar', 'baz', 'baz',
                     'foo', 'foo', 'qux', 'qux'],
                    ['one', 'two', 'one', 'two',
                     'one', 'two', 'one', 'two']])
zip
# Out:
# <function zip>
